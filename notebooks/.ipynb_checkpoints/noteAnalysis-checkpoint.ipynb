# %%
pip install pandas matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\guidf\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\guidf\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\guidf\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\guidf\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\guidf\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\guidf\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\guidf\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\guidf\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guidf\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\guidf\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guidf\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\guidf\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\guidf\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\guidf\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\guidf\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\guidf\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\guidf\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\guidf\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\guidf\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/database_saopaulo.csv')

df['Data'] = pd.to_datetime(df['Data'], format="%d/%m/%Y")

def playedOscar(df):
    if df['Data'] >= pd.Timestamp('2025-01-23'):
        return 'Sim'
    else:
        return 'Não'
df['Oscar Jogou?'] = df.apply(playedOscar, axis=1)

df['Passes Totais (Oscar)'] = df['Passes Totais (Oscar)'].fillna(0)
df['Passes Certos (Oscar)'] = df['Passes Certos (Oscar)'].fillna(0)
df['Passes Decisivos (Oscar)'] = df['Passes Decisivos (Oscar)'].fillna(0)
df['Gols (Oscar)'] = df['Gols (Oscar)'].fillna(0)
df['Assistências (Oscar)'] = df['Assistências (Oscar)'].fillna(0)
df['Chutes (Oscar)'] = df['Chutes (Oscar)'].fillna(0)

df['Passes Totais (Oscar)'] = df['Passes Totais (Oscar)'].astype(int)
df['Passes Certos (Oscar)'] = df['Passes Certos (Oscar)'].astype(int)
df['Passes Decisivos (Oscar)'] = df['Passes Decisivos (Oscar)'].astype(int)
df['Gols (Oscar)'] = df['Gols (Oscar)'].astype(int)
df['Assistências (Oscar)'] = df['Assistências (Oscar)'].astype(int)
df['Chutes (Oscar)'] = df['Chutes (Oscar)'].astype(int)

df['Posse (%)'] = df['Posse (%)'].str.replace('%', '', regex=False)
df['Posse (%)'] = df['Posse (%)'].astype(float)

df['Pontuação SofaScore (Oscar)'] = df['Pontuação SofaScore (Oscar)'].str.replace(',', '.', regex=False)
df['Pontuação SofaScore (Oscar)'] = df['Pontuação SofaScore (Oscar)'].astype(float)
df['Pontuação SofaScore (Oscar)'] = df['Pontuação SofaScore (Oscar)'].fillna(0)

df['Passes Certos (%)'] = ((df['Passes Certos'] * 100)/df['Passes Totais']).astype(float).round(1)
df['Passes Certos (Oscar) (%)'] = ((df['Passes Certos (Oscar)'] * 100)/df['Passes Totais (Oscar)']).astype(float).round(1)
df['Passes Certos (Oscar) (%)'] = df['Passes Certos (Oscar) (%)'].fillna(0)
df['Passes Certos (SP X Oscar) (%)'] = ((df['Passes Certos (Oscar)'] * 100)/df['Passes Certos']).astype(float).round(1)
df['Participações Decisivas (Oscar)'] = df[['Passes Decisivos (Oscar)', 'Gols (Oscar)', 'Assistências (Oscar)']].sum(axis=1).astype(int)
df['Aproveitamento (Oscar) (%)'] = (((df['Gols (Oscar)'] + df['Assistências (Oscar)']) * 100)/df['Participações Decisivas (Oscar)']).astype(float).round(1)
df['Aproveitamento (Oscar) (%)'] = df['Aproveitamento (Oscar) (%)'].fillna(0)
df['Gols Esperados (Oscar)'] = df['Gols (Oscar)']/df['Chutes (Oscar)']
df['Gols Esperados (Oscar)'] = df['Gols Esperados (Oscar)'].fillna(0)

df = df.rename(columns={
    'Chances Criadas (SPFC)': 'Chances Criadas'
})

mediaPassesOscar = df[df['Oscar Jogou?'] == 'Sim']['Passes Certos (SP X Oscar) (%)'].mean().round(1)
mediaPassesCertosOscar = df[df['Oscar Jogou?'] == 'Sim']['Passes Certos (Oscar) (%)'].mean().round(1)

mediaChancesOscar = df[df['Oscar Jogou?'] == 'Sim']['Chances Criadas'].mean().round(1)
mediaChances = df[df['Oscar Jogou?'] == 'Não']['Chances Criadas'].mean().round(1)

mediaChutesOscar = df[df['Oscar Jogou?'] == 'Sim']['Chutes'].mean().round(1)
mediaChutes = df[df['Oscar Jogou?'] == 'Não']['Chutes'].mean().round(1)

mediaParticipações = df[df['Oscar Jogou?'] == 'Sim']['Participações Decisivas (Oscar)'].mean().round(1)

mediaAproveitamento = df[df['Oscar Jogou?'] == 'Sim']['Aproveitamento (Oscar) (%)'].mean().round(1)

mediaPontuação = df[df['Oscar Jogou?'] == 'Sim']['Pontuação SofaScore (Oscar)'].mean().round(1)

mediaAss = df[df['Oscar Jogou?'] == 'Sim']['Assistências (Oscar)'].mean().round(1)
mediaGols = df[df['Oscar Jogou?'] == 'Sim']['Gols (Oscar)'].mean().round(1)

chutesEsperados = df[df['Oscar Jogou?'] == 'Sim']['Gols Esperados (Oscar)'].mean().round(1)

jogados = df[df['Oscar Jogou?'] == 'Sim']['Jogo'].count()
naoJogados = df[df['Oscar Jogou?'] == 'Não']['Jogo'].count()

print('=== ANÁLISE: ======================================================================================================')
print(f'Nesta análise, contém {jogados} jogos que o Oscar participou e {naoJogados} que ele não participou.')

print('\n-- Sobre o São Paulo: --')
print(f'Chances criadas SEM Oscar: {mediaChances}')
print(f'Chances criadas COM Oscar: {mediaChancesOscar}')
print(f'\nChutes por jogo SEM Oscar: {mediaChutes}')
print(f'Chutes por jogo COM Oscar: {mediaChutesOscar}')

print('\n-- Sobre o Oscar: --')
print(f'Pontuação SofaScore média: {mediaPontuação}')
print(f'\nOscar participa, em média, de {mediaPassesOscar}% dos passes certos do time com aproveitamento médio de {mediaPassesCertosOscar}%')
print(f'\nOscar participa em média de {mediaParticipações} ações decisivas por jogo, com aproveitamento (resultando em gols) de {mediaAproveitamento}%')
print(f'\nAssistências por jogo: {mediaAss}')
print(f'Gols por jogo: {mediaGols}')
print(f'Gols esperados por chute: {chutesEsperados}')

print('\n===================================================================================================================')

df.to_csv('../data/database_saopaulo_cleaned.csv', index=False)
# Out:
# === ANÁLISE: ======================================================================================================
# Nesta análise, contém 2 jogos que o Oscar participou e 8 que ele não participou.
#
# -- Sobre o São Paulo: --
# Chances criadas SEM Oscar: 1.5
# Chances criadas COM Oscar: 3.0
#
# Chutes por jogo SEM Oscar: 11.0
# Chutes por jogo COM Oscar: 12.0
#
# -- Sobre o Oscar: --
# Pontuação SofaScore média: 8.1
#
# Oscar participa, em média, de 10.5% dos passes certos do time com aproveitamento médio de 86.4%
#
# Oscar participa em média de 3.5 ações decisivas por jogo, com aproveitamento (resultando em gols) de 25.0%
#
# Assistências por jogo: 0.5
# Gols por jogo: 0.5
# Gols esperados por chute: 0.5
#
# ===================================================================================================================
